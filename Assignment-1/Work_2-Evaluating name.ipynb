# %%
 print("your name is",name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-342c487a5ecf> in <module>()
# ----> 1 print("your name is",name)
#
# NameError: name 'name' is not defined

# %%
name=("Azarath Ameen")
print("your name is",name)
# Out:
# your name is Azarath Ameen
